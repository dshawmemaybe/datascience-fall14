# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
countries = pd.read_csv('countries.csv')
players = pd.read_csv('players.csv')
events = pd.read_csv('events.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
players['name'].str.extract('(^[AEIOU])').count()
# Out:
# 84

# %%
players[players.country_id == 'USA'][players.name.str.contains('^A')]
# Out:
# /usr/lib/python2.7/dist-packages/pandas/core/frame.py:1686: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
#                                         name   player_id country_id  \
# 1   Aaron Peirsol                             PEIRSAAR01        USA
# 3   Adam Nelson                               NELSOADA01        USA
# 15  Allyson Felix                             FELIXALL01        USA
# 16  Alvin Harrison                            HARRIALV01        USA
# 17  Amanda Beard                              BEARDAMA01        USA
# 18  Amanda Weir                               WEIRAMA01         USA
# 19  Amy van Dyken                             VANDYAMY01        USA
# 25  Angelo Taylor                             TAYLOANG02        USA
# 30  Anthony Ervin                             ERVINANT01        USA
# 32  Antonio Pettigrew                         PETTIANT01        USA
#
#      birthdate
# 1   1978-08-26
# ...

# %%
pd.DataFrame(players.groupby('country_id').size().to_dict().items(), columns = ['country_name', 'num_players'])
# Out:
#    country_name  num_players
# 0           BAR            1
# 1           NGR           12
# 2           USA           88
# 3           DOM            1
# 4           NED           13
# 5           MOZ            1
# 6           SWE            9
# 7           UKR            9
# 8           CRC            1
# 9           GBR           12
# 10          CAN            1
# 11          DEN            2
# 12          ISL            1
# 13          ETH           12
# 14          CRO            1
# 15          BAH            5
# 16          GER           22
# 17          ROM           10
# 18          HUN            4
# 19          POR            3
# 20          ERI            1
# 21          CMR            1
# 22          POL            5
# 23          BUL            1
# 24          TRI            2
# 25          FRA           10
# 26          EST            2
# 27          SVK            1
# 28          LTU            2
# 29          ESP            4
# 30          SLO            1
# ...

# %%
pd.merge(countries, players, how='left', on='country_id')[players.birthdate > '1974-12-31'][players.birthdate < '1976-01-01'].groupby('country_id').size()
# Out:
# country_id
# AUS           4
# BLR           1
# BRA           2
# CUB           4
# ETH           1
# FRA           1
# GER           3
# GRE           1
# ITA           1
# JPN           1
# KEN           2
# KSA           1
# NED           1
# NOR           1
# RUS           3
# SWE           1
# USA           4
# dtype: int64

# %%
print "The next step would be to find the countries that aren't in the above list, and to concatenate them to above with a value of 0"
# Out:
# The next step would be to find the countries that aren't in the above list, and to concatenate them to above with a value of 0
